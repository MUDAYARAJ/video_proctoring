# %%
#import cv2, numpy and matplotlib libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread("geesks.png")
#Displaying image using plt.imshow() method
plt.imshow(img)

#hold the window

# %%
# Python program to explain cv2.imread() method

# importing cv2
import cv2
from google.colab.patches import cv2_imshow

# path
path = r'geesks.png'

# Using cv2.imread() method
# Using 0 to read image in grayscale mode
img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)

# Displaying the image
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=300x243 at 0x7FBE8C9C7CD0>

# %%
img1=cv2.imread("star.jpg")
img2=cv2.imread("diamond.jpg")

add=cv2.add(img1, img2)
cv2_imshow( add)
sub = cv2.subtract(img1, img2)
  
# the window showing output image
# with the subtracted image 
cv2_imshow( sub)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7FBE8C9EB370>
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7FBE8BDE3100>

# %%
img = cv2.imread('joshi.jpg', cv2.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
edges = cv2.Canny(img,10,50)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# Python program to illustrate
# arithmetic operation of
# addition of two images
	
# organizing imports
import cv2
import numpy as np
	
# path to input images are specified and
# images are loaded with imread command
image1 = cv2.imread('1.jpg')
image2 = cv2.imread('2.jpg')

# cv2.addWeighted is applied over the
# image inputs with applied parameters
weightedSum = cv2.addWeighted(image1, 0.5, image2, 0.4, 0)

# the window showing output image
# with the weighted sum
cv2_imshow(weightedSum)

# De-allocate any associated memory usage
if cv2.waitKey(0) & 0xff == 27:
	cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=500x250 at 0x7FBE8BDEEDA0>

# %%
import cv2
import numpy as np

img = cv2.imread('joshi.jpg')

res = cv2.resize(img,None,fx=2, fy=2, interpolation = cv2.INTER_CUBIC)

#OR

height, width = img.shape[:2]
res = cv2.resize(img,(2*width, 2*height), interpolation = cv2.INTER_CUBIC)
